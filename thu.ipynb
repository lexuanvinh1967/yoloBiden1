# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)

from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/yoloBiden
# Out:
# /content/drive/MyDrive/yoloBiden

# %%
import os
os.listdir()
# Out:
# ['Untitled0.ipynb']

# %%
# !pwd
# Out:
# /content/drive/MyDrive/yoloBiden/yolov5

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9993, done.
# remote: Total 9993 (delta 0), reused 0 (delta 0), pack-reused 9993
# Receiving objects: 100% (9993/9993), 10.34 MiB | 11.35 MiB/s, done.
# Resolving deltas: 100% (6926/6926), done.

# %%
cd yolov5
# Out:
# /content/drive/My Drive/yoloBiden/yolov5

# %%
# !pip install -r requirements.txt

# %%
! unrar x /content/drive/MyDrive/yoloBiden/coco128.rar

# %%
# Train YOLOv5s on COCO128 for 3 epochs
! python /content/drive/MyDrive/yoloBiden/yolov5/train.py --img 640 --batch 16 --epochs 200 --data coco128.yaml --weights yolov5s.pt

# %%
# !python /content/drive/MyDrive/yoloBiden/yolov5/detect.py --source '/content/drive/MyDrive/VIDU/video_xedem.mp4'
